# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")
sns.set(rc={'figure.figsize': [15, 15]}, font_scale=1.3)

# %%
df=pd.read_csv('airbnb listings.csv')
df.head(10)
# Out:
#       id                                              name  host_id  \
# 0   2015  Berlin-Mitte Value! Quiet courtyard/very central     2217
# 1   2695                Prenzlauer Berg close to Mauerpark     2986
# 2   3176                   Fabulous Flat in great Location     3718
# 3   3309                 BerlinSpot Schöneberg near KaDeWe     4108
# 4   7071                  BrightRoom with sunny greenview!    17391
# 5   9991               Geourgeous flat - outstanding views    33852
# 6  14325                      Apartment in Prenzlauer Berg    55531
# 7  16401                                 APARTMENT TO RENT    59666
# 8  16644                In the Heart of Berlin - Kreuzberg    64696
# 9  17409                Downtown Above The Roofs In Berlin    67590
#
#         host_name       neighbourhood_group             neighbourhood  \
# 0             Ian                     Mitte           Brunnenstr. Süd
# 1         Michael                    Pankow  Prenzlauer Berg Nordwest
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 16 columns):
# id                                22552 non-null int64
# name                              22493 non-null object
# host_id                           22552 non-null int64
# host_name                         22526 non-null object
# neighbourhood_group               22552 non-null object
# neighbourhood                     22552 non-null object
# latitude                          22552 non-null float64
# longitude                         22552 non-null float64
# room_type                         22552 non-null object
# price                             22552 non-null int64
# minimum_nights                    22552 non-null int64
# number_of_reviews                 22552 non-null int64
# last_review                       18644 non-null object
# reviews_per_month                 18638 non-null float64
# calculated_host_listings_count    22552 non-null int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.255200e+04  2.255200e+04  22552.000000  22552.000000  22552.000000
# mean   1.571560e+07  5.403355e+07     52.509824     13.406107     67.143668
# std    8.552069e+06  5.816290e+07      0.030825      0.057964    220.266210
# min    2.015000e+03  2.217000e+03     52.345803     13.103557      0.000000
# 25%    8.065954e+06  9.240002e+06     52.489065     13.375411     30.000000
# 50%    1.686638e+07  3.126711e+07     52.509079     13.416779     45.000000
# 75%    2.258393e+07  8.067518e+07     52.532669     13.439259     70.000000
# max    2.986735e+07  2.245081e+08     52.651670     13.757642   9000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    22552.000000       22552.000000       18638.000000
# mean         7.157059          17.840679           1.135525
# std         40.665073          36.769624           1.507082
# ...

# %%
df['name']
# Out:
# 0         Berlin-Mitte Value! Quiet courtyard/very central
# 1                       Prenzlauer Berg close to Mauerpark
# 2                          Fabulous Flat in great Location
# 3                        BerlinSpot Schöneberg near KaDeWe
# 4                         BrightRoom with sunny greenview!
#                                ...
# 22547         Cozy Apartment right in the center of Berlin
# 22548               Altbau/ Schöneberger Kiez / Schlafsofa
# 22549     Artists loft with garden in the center of Berlin
# 22550                Room for two with private shower / WC
# 22551    Sunny, modern and cozy flat in Berlin Neukölln :)
# Name: name, Length: 22552, dtype: object

# %%
df['host_id'].value_counts()
# Out:
# 1625771     45
# 8250486     43
# 2293972     30
# 8912086     26
# 59442407    19
#             ..
# 9702668      1
# 14496460     1
# 38341323     1
# 91652810     1
# 1015808      1
# Name: host_id, Length: 19180, dtype: int64

# %%
for i in df.columns:
    print('\n')
    print(i.capitalize(),'\n')
    print(df[i].value_counts())
# Out:
# Id
#
# 16322558    1
# 22768552    1
# 22856204    1
# 23089743    1
# 20064848    1
#            ..
# 27896795    1
# 1033506     1
# 7044389     1
# 18605350    1
# 22043930    1
# Name: id, Length: 22552, dtype: int64
#
#
# Name
#
# Berlin Wohnung                                   14
# Room in Neukölln                                  9
# Cozy room in Berlin                               9
# Gemütliches Zimmer in Neukölln                    9
# Room in Friedrichshain                            8
#                                                  ..
# Spacious apartment in top location                1
# Winner of architecture prize                      1
# Near the city and yet beautifully green           1
# Beautiful private room in cool Friedrichshain     1
# Zimmer in netter WG                               1
# Name: name, Length: 21873, dtype: int64
#
#
# Host_id
#
# 1625771     45
# 8250486     43
# 2293972     30
# 8912086     26
# 59442407    19
#             ..
# ...

# %%
df['neighbourhood'].unique()
# Out:
# array(['Brunnenstr. Süd', 'Prenzlauer Berg Nordwest',
#        'Prenzlauer Berg Südwest', 'Schöneberg-Nord', 'Helmholtzplatz',
#        'Frankfurter Allee Süd FK', 'nördliche Luisenstadt',
#        'Reuterstraße', 'südliche Luisenstadt', 'Tempelhofer Vorstadt',
#        'Prenzlauer Berg Süd', 'Moabit Ost', 'Prenzlauer Berg Nord',
#        'Otto-Suhr-Allee', 'Schillerpromenade', 'Alt  Treptow',
#        'Alexanderplatz', 'Neue Kantstraße', 'Ostpreußendamm',
#        'Schmöckwitz/Karolinenhof/Rauchfangswerder',
#        'Neuköllner Mitte/Zentrum', 'Frankfurter Allee Nord', 'Kantstraße',
#        'Schmargendorf', 'Regierungsviertel', 'Schöneberg-Süd',
#        'Blankenfelde/Niederschönhausen', 'Friedrichshagen',
#        'Südliche Friedrichstadt', 'Moabit West', 'Wiesbadener Straße',
#        'West 3', 'Blankenburg/Heinersdorf/Märchenland',
#        'Rummelsburger Bucht', 'Friedenau', 'Brunnenstr. Nord', 'Ost 2',
#        'Volkspark Wilmersdorf', 'Pankow Zentrum', 'Pankow Süd',
# ...

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Friedrichshain-Kreuzberg    5497
# Mitte                       4631
# Pankow                      3541
# Neukölln                    3499
# Charlottenburg-Wilm.        1592
# Tempelhof - Schöneberg      1560
# Lichtenberg                  688
# Treptow - Köpenick           595
# Steglitz - Zehlendorf        437
# Reinickendorf                247
# Marzahn - Hellersdorf        141
# Spandau                      124
# Name: neighbourhood_group, dtype: int64

# %%
df['room_type'].value_counts()
# Out:
# Private room       11534
# Entire home/apt    10722
# Shared room          296
# Name: room_type, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df['reviews_per_month'].value_counts(sort=True)
# Out:
# 0.03     624
# 0.07     401
# 0.06     360
# 0.10     333
# 0.08     329
#         ...
# 9.77       1
# 7.65       1
# 11.16      1
# 10.67      1
# 8.25       1
# Name: reviews_per_month, Length: 768, dtype: int64

# %%
host_name_values=df['host_name'].value_counts()[:20].values
host_name_index=df['host_name'].value_counts()[:20].index
df_top_20_host=pd.DataFrame({'name':host_name_index,'count':host_name_values})
df_top_20_host
# Out:
#          name  count
# 0        Anna    216
# 1       Julia    171
# 2     Michael    148
# 3      Daniel    132
# 4     Philipp    126
# 5       David    125
# 6         Jan    125
# 7      Martin    125
# 8       Laura    122
# 9   Christian    113
# 10      Maria    113
# 11     Stefan    108
# 12       Lisa    107
# 13  Sebastian    104
# 14     Thomas    103
# 15      Sarah     99
# 16        Max     98
# 17  Katharina     89
# 18       Alex     87
# 19       Anne     86

# %%
plt.figure(figsize=(15,15))
plt.xlabel('name')
plt.ylabel('Count')
plt.xticks(rotation=45)
sns.barplot(x=host_name_index,y=host_name_values,data=df_top_20_host)

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=45)
sns.countplot(x='neighbourhood_group',data=df,hue='room_type')

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='room_type',y='price',data=df,hue='neighbourhood_group')

# %%
sns.boxplot(x='price',data=df)

# %%
sns.scatterplot(x='room_type',y='price',data=df)

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=45)
sns.scatterplot(x='neighbourhood_group',y='price',data=df)

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=45)
sns.scatterplot(x='neighbourhood_group',y='price',data=df)

# %%
sns.boxplot(x='room_type',y='price',data=df,hue='neighbourhood_group')

# %%
sns.boxplot(x='room_type',y='price',data=df,hue='neighbourhood_group')

# %%
df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
# ...

# %%
sns.pairplot(df)
# Out:
# C:\Users\Meagzzz\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Meagzzz\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
from datasist.structdata import detect_outliers
outliers_indices = detect_outliers(df, 1,['price',
       'minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365'])
len(outliers_indices)
# Out:
# C:\Users\Meagzzz\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# 3199

# %%
df.drop(outliers_indices, inplace=True)
df
# Out:
#              id                                               name    host_id  \
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# 5          9991                Geourgeous flat - outstanding views      33852
# 9         17409                 Downtown Above The Roofs In Berlin      67590
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x='room_type',y='price',data=df,hue='neighbourhood_group')

# %%
df[df['price']>=2000].index
# Out:
# Int64Index([1990, 4573, 16915, 19729, 21389], dtype='int64')

# %%
df.loc[[1990, 4573, 16915, 19729, 21389]]
# Out:
#              id                                               name    host_id  \
# 1990    2860420  250 qm penthouse with roof terrace for photoshoot   14623546
# 4573    7024131         Gemütliches Zimmer absolut zentral gelegen   12318581
# 16915  22586252                                                NaN   90556837
# 19729  26294126                    Space for a great time - enjoy!  109992090
# 21389  28462345                    Berlin Apartment Friedrichshain   28957697
#
#       host_name       neighbourhood_group           neighbourhood   latitude  \
# 1990   Jean Luc  Friedrichshain-Kreuzberg    Tempelhofer Vorstadt  52.493489
# 4573       Iris                    Pankow          Helmholtzplatz  52.542833
# 16915     Peter                    Pankow          Helmholtzplatz  52.545980
# 19729  Johannes                     Mitte          Alexanderplatz  52.506901
# 21389    Caspar  Friedrichshain-Kreuzberg  Frankfurter Allee Nord  52.518353
#
# ...

# %%
df.drop(axis=0,index=[1990, 4573, 16915, 19729, 21389],inplace=True)

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 1   2695   Prenzlauer Berg close to Mauerpark     2986   Michael
# 3   3309    BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4   7071     BrightRoom with sunny greenview!    17391    Bright
# 5   9991  Geourgeous flat - outstanding views    33852   Philipp
# 9  17409   Downtown Above The Roofs In Berlin    67590   Wolfram
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
# 5                  Pankow   Prenzlauer Berg Südwest  52.533031  13.416047
# 9                  Pankow   Prenzlauer Berg Südwest  52.529071  13.412843
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x='room_type',y='price',data=df,hue='neighbourhood_group')

# %%
df[df['price']>=400].index
# Out:
# Int64Index([ 1270,  3192,  3260,  4123,  4328,  4342,  7913,  8315,  8702,
#              8898,  8967, 11471, 11542, 14586, 16983, 18662, 19045, 19086,
#             19330, 22332],
#            dtype='int64')

# %%
df.drop(axis=0,index=[ 1270,  3192,  3260,  4123,  4328,  4342,  7913,  8315,  8702,
             8898,  8967, 11471, 11542, 14586, 16983, 18662, 19045, 19086,
            19330, 22332],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19328 entries, 1 to 22551
# Data columns (total 16 columns):
# id                                19328 non-null int64
# name                              19271 non-null object
# host_id                           19328 non-null int64
# host_name                         19304 non-null object
# neighbourhood_group               19328 non-null object
# neighbourhood                     19328 non-null object
# latitude                          19328 non-null float64
# longitude                         19328 non-null float64
# room_type                         19328 non-null object
# price                             19328 non-null int64
# minimum_nights                    19328 non-null int64
# number_of_reviews                 19328 non-null int64
# last_review                       15923 non-null object
# reviews_per_month                 15917 non-null float64
# calculated_host_listings_count    19328 non-null int64
# ...

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x='room_type',y='reviews_per_month',data=df)

# %%
df[df['reviews_per_month']>=10].index
# Out:
# Int64Index([8971, 20320, 20446, 21113, 21538, 21837], dtype='int64')

# %%
df.drop(axis=0,index=[8971,20320, 20446, 21113, 21538, 21837],inplace=True)

# %%
df.fillna(value=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19322 entries, 1 to 22551
# Data columns (total 16 columns):
# id                                19322 non-null int64
# name                              19322 non-null object
# host_id                           19322 non-null int64
# host_name                         19322 non-null object
# neighbourhood_group               19322 non-null object
# neighbourhood                     19322 non-null object
# latitude                          19322 non-null float64
# longitude                         19322 non-null float64
# room_type                         19322 non-null object
# price                             19322 non-null int64
# minimum_nights                    19322 non-null int64
# number_of_reviews                 19322 non-null int64
# last_review                       19322 non-null object
# reviews_per_month                 19322 non-null float64
# calculated_host_listings_count    19322 non-null int64
# ...

# %%
df['neighbourhood'].unique()
# Out:
# array(['Prenzlauer Berg Nordwest', 'Schöneberg-Nord', 'Helmholtzplatz',
#        'Prenzlauer Berg Südwest', 'Reuterstraße', 'Prenzlauer Berg Süd',
#        'Frankfurter Allee Süd FK', 'Prenzlauer Berg Nord',
#        'Otto-Suhr-Allee', 'Schillerpromenade', 'südliche Luisenstadt',
#        'Alt  Treptow', 'Alexanderplatz', 'Neue Kantstraße',
#        'Brunnenstr. Süd', 'Ostpreußendamm',
#        'Schmöckwitz/Karolinenhof/Rauchfangswerder',
#        'Frankfurter Allee Nord', 'Schmargendorf', 'Schöneberg-Süd',
#        'Blankenfelde/Niederschönhausen', 'Tempelhofer Vorstadt',
#        'Friedrichshagen', 'Südliche Friedrichstadt', 'West 3',
#        'nördliche Luisenstadt', 'Blankenburg/Heinersdorf/Märchenland',
#        'Rummelsburger Bucht', 'Friedenau', 'Wiesbadener Straße',
#        'Brunnenstr. Nord', 'Neuköllner Mitte/Zentrum', 'Ost 2',
#        'Volkspark Wilmersdorf', 'Pankow Süd', 'Osloer Straße',
#        'Drakestr.', 'West 1', 'Buckow Nord', 'Karl-Marx-Allee-Nord',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le.fit_transform(df['neighbourhood'])
# Out:
# array([ 94, 109,  48, ...,  97,   2, 104])

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Pankow', 'Tempelhof - Schöneberg', 'Neukölln',
#        'Friedrichshain-Kreuzberg', 'Charlottenburg-Wilm.',
#        'Treptow - Köpenick', 'Mitte', 'Steglitz - Zehlendorf',
#        'Reinickendorf', 'Lichtenberg', 'Marzahn - Hellersdorf', 'Spandau'],
#       dtype=object)

# %%
df = pd.get_dummies(df, columns=['neighbourhood_group', 'room_type'])

# %%
df.head()
# Out:
#       id                                 name  host_id host_name  \
# 1   2695   Prenzlauer Berg close to Mauerpark     2986   Michael
# 3   3309    BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4   7071     BrightRoom with sunny greenview!    17391    Bright
# 5   9991  Geourgeous flat - outstanding views    33852   Philipp
# 9  17409   Downtown Above The Roofs In Berlin    67590   Wolfram
#
#               neighbourhood   latitude  longitude  price  minimum_nights  \
# 1  Prenzlauer Berg Nordwest  52.548513  13.404553     17               2
# 3           Schöneberg-Nord  52.498855  13.349065     26               5
# 4            Helmholtzplatz  52.543157  13.415091     42               2
# 5   Prenzlauer Berg Südwest  52.533031  13.416047    180               6
# 9   Prenzlauer Berg Südwest  52.529071  13.412843     45               3
#
#    number_of_reviews  ... neighbourhood_group_Neukölln  \
# 1                  6  ...                            0
# ...

# %%
sns.heatmap(data=df.corr(),cmap="YlGnBu")

# %%
df1=pd.DataFrame(df, columns=['price',
       'minimum_nights', 'number_of_reviews',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365'])

# %%
df1
# Out:
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 1         17               2                  6               1.42
# 3         26               5                 25               0.39
# 4         42               2                197               1.75
# 5        180               6                  6               0.15
# 9         45               3                279               2.83
# ...      ...             ...                ...                ...
# 22547     60               2                  0               0.00
# 22548     20               1                  0               0.00
# 22549     85               3                  0               0.00
# 22550     99               1                  0               0.00
# 22551     45               5                  0               0.00
#
#        calculated_host_listings_count  availability_365
# 1                                   1                 0
# ...

# %%
sns.pairplot(df1)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'neighbourhood_group_Charlottenburg-Wilm.',
#        'neighbourhood_group_Friedrichshain-Kreuzberg',
#        'neighbourhood_group_Lichtenberg',
#        'neighbourhood_group_Marzahn - Hellersdorf',
#        'neighbourhood_group_Mitte', 'neighbourhood_group_Neukölln',
#        'neighbourhood_group_Pankow', 'neighbourhood_group_Reinickendorf',
#        'neighbourhood_group_Spandau',
#        'neighbourhood_group_Steglitz - Zehlendorf',
#        'neighbourhood_group_Tempelhof - Schöneberg',
#        'neighbourhood_group_Treptow - Köpenick', 'room_type_Entire home/apt',
#        'room_type_Private room', 'room_type_Shared room'],
#       dtype='object')

# %%
x=df[['latitude',
       'longitude', 'price', 'minimum_nights', 'number_of_reviews',
      'reviews_per_month', 'calculated_host_listings_count',
       'availability_365', 'neighbourhood_group_Charlottenburg-Wilm.',
       'neighbourhood_group_Friedrichshain-Kreuzberg',
       'neighbourhood_group_Lichtenberg',
       'neighbourhood_group_Marzahn - Hellersdorf',
       'neighbourhood_group_Mitte', 'neighbourhood_group_Neukölln',
       'neighbourhood_group_Pankow', 'neighbourhood_group_Reinickendorf',
       'neighbourhood_group_Spandau',
       'neighbourhood_group_Steglitz - Zehlendorf',
       'neighbourhood_group_Tempelhof - Schöneberg',
       'neighbourhood_group_Treptow - Köpenick', 'room_type_Entire home/apt',
       'room_type_Private room', 'room_type_Shared room']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=90)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([33. , 54.8, 17.6, ..., 53.6, 35. , 25. ])

# %%
y_test
# Out:
# 17902    33
# 6848     55
# 5189     18
# 14759    50
# 17341    20
#          ..
# 19101    70
# 8118     21
# 13687    53
# 15060    35
# 6047     25
# Name: price, Length: 3865, dtype: int64

# %%
model.score(x_train, y_train)
# Out:
# 0.9964247897711938

# %%
model.score(x_test, y_test)
# Out:
# 0.9941546667214134

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
from sklearn.model_selection import GridSearchCV
param_grid = [{'max_depth': np.arange(1, 10),
              'min_samples_leaf': [1, 5, 10, 20, 50, 100],
              'min_weight_fraction_leaf': [0.0,0.1,0.3,0.5],
              'random_state':[1,3,4,7]}]
gridCV = GridSearchCV(estimator=regressor, param_grid=param_grid,cv=10)
gridCV = gridCV.fit(x_train, y_train)
print(gridCV.best_score_)
print(gridCV.best_params_)
# Out:
# 0.9999402667354325
# {'max_depth': 8, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.0, 'random_state': 4}
